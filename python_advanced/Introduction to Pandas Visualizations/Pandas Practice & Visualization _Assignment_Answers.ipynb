# %% [markdown]
# # **Day 2 — Assignment**
#
# **Pandas Practice & Visualization — winequality-white.csv**

# %% [markdown]
# **Section 1 — Pandas Practice**
#
# **Task 1:** Import pandas, read winequality-white.csv into a DataFrame, and run shape
# and info() to confirm it loaded correctly.

# %%
import pandas as pd             # import pandas

# %%
df = pd.read_csv("../data/winequality-white.csv", delimiter=";")    # load the data

# %%
print(df.shape)
print(df.info())
# Out:
# (4898, 12)
# <class 'pandas.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB
# None

# %% [markdown]
# **Task 2:** Display the first 7 values of the 'volatile acidity' column.

# %%
df["volatile acidity"].head(7)
# Out:
# 0    0.27
# 1    0.30
# 2    0.28
# 3    0.23
# 4    0.23
# 5    0.28
# 6    0.32
# Name: volatile acidity, dtype: float64

# %% [markdown]
# **Task 3:** Build a mask for rows where volatile acidity is less than 0.3, and count how
# many rows match.

# %%
df[df["volatile acidity"] < 0.3]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# 5               8.1              0.28         0.40             6.9      0.050
# ...             ...               ...          ...             ...        ...
# 4892            6.5              0.23         0.38             1.3      0.032
# 4893            6.2              0.21         0.29             1.6      0.039
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# 3163 rows as shown above

# %% [markdown]
# **Task 4:** Add a second condition to that same mask — quality of 7 or higher — and
# count how many rows match both conditions together.

# %%
df[(df["volatile acidity"] < 0.3) & (df["quality"] >= 7)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 13              6.6              0.16         0.40             1.5      0.044
# 15              6.6              0.17         0.38             1.5      0.032
# 22              6.8              0.26         0.42             1.7      0.049
# 45              7.4              0.18         0.31             1.4      0.058
# 51              6.6              0.25         0.29             1.1      0.068
# ...             ...               ...          ...             ...        ...
# 4802            5.8              0.28         0.34             2.2      0.037
# 4812            5.1              0.26         0.33             1.1      0.027
# 4823            6.5              0.28         0.34             4.6      0.054
# 4886            6.2              0.21         0.28             5.7      0.028
# 4896            5.5              0.29         0.30             1.1      0.022
#
# ...

# %% [markdown]
# 698 rows for both conditions

# %% [markdown]
# **Task 5:** Group the data by quality and find the average pH for each quality score.

# %%
df.groupby(["quality"]).mean()["pH"]
# Out:
# quality
# 3    3.187500
# 4    3.182883
# 5    3.168833
# 6    3.188599
# 7    3.213898
# 8    3.218686
# 9    3.308000
# Name: pH, dtype: float64

# %% [markdown]
# **Task 6**: Sort the DataFrame by residual sugar in descending order and show the top 8
# rows, displaying only the residual sugar and quality columns.

# %%
df.sort_values(["residual sugar"], ascending=False)[["residual sugar", "quality"]].head(8)
# Out:
#       residual sugar  quality
# 2781           65.80        6
# 1663           31.60        6
# 1653           31.60        6
# 3623           26.05        6
# 3619           26.05        6
# 1608           23.50        5
# 4480           22.60        5
# 182            22.00        5

# %% [markdown]
# **Section 2 — Visualization with pandas' built-in .plot()**
#
# **Task 7:** Create a histogram of the pH column.

# %%
df["pH"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# **Task 8:** Create a scatter plot with sulphates on the x-axis and alcohol on the y-axis.

# %%
df.plot(kind="scatter", x="sulphates", y="alcohol")
# Out:
# <Axes: xlabel='sulphates', ylabel='alcohol'>

# %% [markdown]
# **Task 9:** Create a box plot of every column in the DataFrame at once. Then create a
# second box plot using only fixed acidity and alcohol. What's different about how
# readable the two box plots are, and why?

# %%
df.plot(kind="box")             # all at once
# Out:
# <Axes: >

# %%
df[["fixed acidity", "alcohol"]].plot(kind="box")
# Out:
# <Axes: >

# %% [markdown]
# First, you can't read the labels with many columns on display. Second, you can't really distinguish their distributions, since the scales of the columns differ significantly.

# %% [markdown]
# **Task 10:** Create a box plot of the citric acid column on its own.

# %%
df["citric acid"].plot(kind='box')
# Out:
# <Axes: >
