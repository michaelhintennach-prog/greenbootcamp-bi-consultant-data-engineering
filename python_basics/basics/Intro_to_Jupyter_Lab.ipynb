# %% [markdown]
# ## Intro to Jupyter Lab

# %% [markdown]
# Here we are starting with another tool: Jupyter Lab. You will soon see, that there are many similarities to Colab, so it's not a <br> huge stretch to get aquainted here too. <br>
#
#         Note: If you are using an IDE (integrated development environment) like VSCode some keyboard short cuts may differ.

# %% [markdown]
# ### Objectives

# %% [markdown]
# By the end of this notebooks, you will be able to:
# - run cells in jupyter lab and change them to markdown or code cell
# - differentiate between Command and Edit Mode and to change between them
# - run UNIX commands in Jupyter Lab
# - receiving help from docstrings

# %% [markdown]
# ### Running cells

# %% [markdown]
# **Welcome to programming**!! Juptyer Notebooks (historically called IPython Notebooks) will be our primary tool to get in to while starting data science. <br> The first thing to know with this is that each cell block [of code] can be run be pressing shift+enter. Try running the below code block:

# %%
print('The code is running.')
# Out:
# The code is running.

# %% [markdown]
# ### Cell types

# %% [markdown]
# You might have started to notice that the code blocks have little notes that say In **[ ]**: before you run them, and then are filled with a  number after <br> you run them. This is important, as it tells you what order cell blocks were run. (Which can sometimes affect how a program runs.)

# %% [markdown]
# You may also notice that other cell blocks, such as this one, do not have the In **[ ]**: label as with the code blocks. This is because this <br> cell block is formatted as Markdown (rather then code. The details of Markdown are not important here but just know you can use <br> markdown cell blocks to display text. They are really useful for adding notes and explanations in your Jupyter Notebook. You can <br> see (and change) what type of cell is by clicking the dropdown menu at the top.

# %% [markdown]
# ## Command vs edit mode

# %% [markdown]
# We distinguish between two modes in jupyter lab, one is the edit mode where you can write code or notes, the other is the command <br> mode where you can delete or copy cells.

# %% [markdown]
# To switch from edit mode to command mode, you can press **esc**, (you cannot write in the cell now) and press Enter to **enter** edit mode <br> again.

# %% [markdown]
# ### Edit mode
# Edit mode is the standard mode for editing cells, whether it's writing code or notes. To enter edit mode from command mode simply hit <br> enter, or double click on a cell.

# %% [markdown]
# ### Command mode
# In command mode, you can delete cells, add cells, copy cells, paste cells, change cell types, and more. You can also do these tasks in <br> a more time consuming manner by using the various headers in the menu bar at top.
# If you want to learn more about the<br> functionalities of jupyter lab, here is the here is the [documentation](https://jupyterlab.readthedocs.io/en/latest/).

# %% [markdown]
# ## Running Bash Commands

# %% [markdown]
# We can also run bash commands just as we did before, from the terminal directly within Jupyter Notebooks! <br>
# (Note: bash commands cannot be mixed with python and must be in their own cell block.)

# %% [markdown]
# Try it out!

# %%
pwd
# Out:
# 'C:\\Users\\micha\\Greenbootcamp\\DS_Python_basics'

# %%
ls
# Out:
#  Datentr„ger in Laufwerk C: ist Windows-SSD
#  Volumeseriennummer: B4AD-FAEA
#
#  Verzeichnis von C:\Users\micha\Greenbootcamp\DS_Python_basics
#
# 17.06.2026  10:00    <DIR>          .
# 16.06.2026  15:04    <DIR>          ..
# 16.06.2026  10:42             1.979 .gitignore
# 17.06.2026  09:28    <DIR>          .ipynb_checkpoints
# 16.06.2026  11:54    <DIR>          _venv
# 16.06.2026  10:42            11.136 Bash_basics.ipynb
# 16.06.2026  10:42    <DIR>          Basics
# 16.06.2026  10:42            10.503 Coding_best_practices.ipynb
# 16.06.2026  10:42    <DIR>          Data_Structures_Python
# 16.06.2026  10:42    <DIR>          Functions
# 16.06.2026  10:42    <DIR>          images
# 17.06.2026  10:00            10.623 Intro_to_Jupyter_Lab.ipynb
# 16.06.2026  10:42             1.095 LICENSE
# 16.06.2026  10:42             1.478 README.md
# 16.06.2026  10:42                55 requirements.txt
#                7 Datei(en),         36.869 Bytes
# ...

# %% [markdown]
# ## Autocomplete and getting Help

# %% [markdown]
# Like in Colab there is the autocomplete function. When you start typing code, you can see a subset of the available commands **when <br> you press tab**. You can use "enter" to auto-complete the first command, otherwise you can use the arrow keys to scroll through all the <br> commands and press "enter" to complete the command.

# %% [markdown]
# ## Call Docstrings

# %% [markdown]
# And of course docstrings are working here too! You can do this by writing ? after the method and executing the cell:

# %% [markdown]
# Or you use shift + tab to get help automatically without executing the cell.

# %% [markdown]
# Try it out!

# %% [markdown]
# ## Stop Execution

# %% [markdown]
# Long running python processes can be interrupted. Run the following cell and select **Kernel -> Interrupt kernel** to stop execution. <br> Try it out:

# %%
import time
print("Sleeping")
time.sleep(30) # sleep for a while; interrupt me!
print("Done Sleeping")
# Out:
# Sleeping
# Done Sleeping

# %% [markdown]
# Sometimes Notebooks can get a bit messy. In order for you and others to go through your notebook smoothly, it is<br> important that the cells are executed in the correct order (from top to bottom). To check if this is possible, we<br> recommend that you run **Kernel --> Restart Kernel and Run All Cells...** every now and then.

# %% [markdown]
# # Check your understanding!

# %% [markdown]
# Try to do all these tasks with shortcuts! Of course, feel free to test other shortcuts to get more familiar with them too.
#
# 1. Create a new cell below.
# 2. Change the celltype to "markdown"
# 3. Enter the cell and write "print('Gratulation! You are now familiar with jupyter lab!')"
# 4. Exit the edit mode and change celltype to "Code"
# 5. Copy the cell and paste it below.
# 6. Delete the last cell again.
# 7.Run the cell --> you're done :)

# %%
print('Gratulation! You are now familiar with jupyter lab!')
# Out:
# Gratulation! You are now familiar with jupyter lab!
