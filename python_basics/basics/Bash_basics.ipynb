# %% [markdown]
# # Bash

# %% [markdown]
# Bash is a Unix shell and command language, a command-line interpreter. Lets have a look in to some of the basic commands in ```Bash``` for you <br> to try here in VS code or in Terminal. Please note that all bash commands won't be working in code cell here! So recommendation<br> would be to try it in Terminal

# %% [markdown]
# The current path where you are residing can be seen by using the command:

# %%
pwd
# Out:
# 'C:\\Users\\micha\\Greenbootcamp\\DS_Python_basics'

# %% [markdown]
# You can list the content of your home directory using

# %%
ls
# Out:
#  Datentr„ger in Laufwerk C: ist Windows-SSD
#  Volumeseriennummer: B4AD-FAEA
#
#  Verzeichnis von C:\Users\micha\Greenbootcamp\DS_Python_basics
#
# 17.06.2026  10:35    <DIR>          .
# 16.06.2026  15:04    <DIR>          ..
# 16.06.2026  10:42             1.979 .gitignore
# 17.06.2026  10:27    <DIR>          .ipynb_checkpoints
# 16.06.2026  11:54    <DIR>          _venv
# 17.06.2026  10:35            10.603 Bash_basics.ipynb
# 16.06.2026  10:42    <DIR>          Basics
# 16.06.2026  10:42            10.503 Coding_best_practices.ipynb
# 16.06.2026  10:42    <DIR>          Data_Structures_Python
# 16.06.2026  10:42    <DIR>          Functions
# 16.06.2026  10:42    <DIR>          images
# 17.06.2026  10:02            10.883 Intro_to_Jupyter_Lab.ipynb
# 16.06.2026  10:42             1.095 LICENSE
# 16.06.2026  10:42             1.478 README.md
# 16.06.2026  10:42                55 requirements.txt
#                7 Datei(en),         36.596 Bytes
#                8 Verzeichnis(se), 395.871.047.680 Bytes frei

# %%
ls -l
# Out:
#  Datentr„ger in Laufwerk C: ist Windows-SSD
#  Volumeseriennummer: B4AD-FAEA
#
#  Verzeichnis von C:\Users\micha\Greenbootcamp\DS_Python_basics
# Datei nicht gefunden

# %% [markdown]
# ```Warning```:<br>
# Do not confuse the lowercase letter ```l``` (as used in ```ls -l```) with the number 1.

# %% [markdown]
# You can clear the terminal by typing:

# %%
clear

# %% [markdown]
# Now, use the up- and down-arrows on your keyboard to look through the history of commands.<br>
#
# Now create a directory:

# %%
mkdir day1

# %% [markdown]
# List content of the directory again:

# %%
ls
ls -l           # This shows you the home directory (and the day1 folder that is within the home directory)
ls -l day1/     # This shows you the content of the day1 folder

# %% [markdown]
# What does mkdir do? Bring up the manual (press “q” to exit the manual).

# %%
man mkdir

# %% [markdown]
# Now create some files. There are many ways to create a file.

# %%
# Create an empty file in directory "day1"
touch day1/touch.txt

# Write the text "abcdefgh" in a file.
echo "abcdefgh"  > day1/echo.txt

# %% [markdown]
# List files again.

# %%
ls
ls -l
ls -l day1/

# %% [markdown]
# Take a look at the file content.

# %%
head day1/*

# %% [markdown]
# ## Files and file systems

# %% [markdown]
# ### Navigate the file system

# %% [markdown]
# First, let’s clean up.

# %%
clear

# %% [markdown]
# Go to the home directory (absolute path).

# %%
cd ~/
ls -l
pwd

# %% [markdown]
# Go to the folder with all home directories (absolute path).

# %%
cd /home
ls -l
pwd

# %% [markdown]
# Go back to your home directory (absolute path).

# %%
cd ~/
ls -l
pwd

# %% [markdown]
# Go into the directory created yesterday (relative path - from your home directory).

# %%
cd day1/
ls -l
pwd

# %% [markdown]
# Go back one level (relative path - from the day1 folder).

# %%
cd ../
ls -l
pwd

# %% [markdown]
# Let’s create another folder (relative path - from your home directory). What does the -p stand for?

# %%
pwd
mkdir -p day2/test/folder
pwd

# %% [markdown]
# Change permissions in a file created in the above folder. We will use the ```chmod``` command (https://en.wikipedia.org/wiki/Chmod). This command uses<br> three digits between 0 and 7 to set the permissions of (i) the user, (ii) the group, and (iii) everyone else. The digit defines the permission, as explained<br> in the following table

# %% [markdown]
# <img src="./images/bash_table.png" width="500"/>

# %% [markdown]
# Now create a test file. Then we will change permissions with ```chmod``` and look at them with ```ls -l```. Rund these lines one by one and understand the <br>output.

# %%
# Create the file
touch day2/test/folder/test.txt
ls -l day2/test/folder

# Change permissions
chmod 711 day2/test/folder/test.txt
ls -l day2/test/folder

chmod 722 day2/test/folder/test.txt
ls -l day2/test/folder

chmod 733 day2/test/folder/test.txt
ls -l day2/test/folder

chmod 744 day2/test/folder/test.txt
ls -l day2/test/folder

chmod 755 day2/test/folder/test.txt
ls -l day2/test/folder

chmod 766 day2/test/folder/test.txt
ls -l day2/test/folder

chmod 777 day2/test/folder/test.txt
ls -l day2/test/folder

chmod 700 day2/test/folder/test.txt
ls -l day2/test/folder

man chmod

# %% [markdown]
# ## Exercises
# 1. Create a new folder called ```test2``` within in the folder ```~/day2```.
# 2. Enable full access to this folder for the owner of the folder, read access for the group, and no access for others
